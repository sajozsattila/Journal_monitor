# %%
version = "1.0.1"

# %% [markdown]
# # Read the Journals which we are searching for

# %%
import pandas as pd

journals = pd.read_csv('doaj_journals.csv', sep="|")
journals.drop_duplicates(inplace=True)
import re
journals.tail
# Out:
# <bound method NDFrame.tail of                                             title        publisher      eissn  \
# 0                                   Acta Acustica     EDP Sciences  2681-4617
# 1                 Adsorption Science & Technology  SAGE Publishing  2048-4038
# 2                                Advanced Science            Wiley  2198-3844
# 3                           Advances in Astronomy  Hindawi Limited  1687-7977
# 4            Advances in Condensed Matter Physics  Hindawi Limited  1687-8124
# ..                                            ...              ...        ...
# 213               REPORTS ON PROGRESS IN PHYSICS               NaN        NaN
# 214         SEMICONDUCTOR SCIENCE AND TECHNOLOGY               NaN        NaN
# 215               SMART MATERIALS AND STRUCTURES               NaN        NaN
# 216          SUPERCONDUCTOR SCIENCE & TECHNOLOGY               NaN        NaN
# 217  SURFACE TOPOGRAPHY-METROLOGY AND PROPERTIES               NaN        NaN
#
#          pissn                            doajid  \
# 0          NaN  5f0e13147bff461c84a8c1037d39a13c
# 1    0263-6174  0717c4a8661b460d917559af2f7592a2
# 2          NaN  12576ad4e52044b08510c86120dad6eb
# 3    1687-7969  77f5de55948a444f81b838436e0b14cb
# 4    1687-8108  dc71831a25644a5eae44b1305582c389
# ..         ...                               ...
# 213        NaN                               NaN
# 214        NaN                               NaN
# 215        NaN                               NaN
# 216        NaN                               NaN
# 217        NaN                               NaN
#
#                                             categories language
# 0    Acoustics in engineering. Acoustical engineeri...       EN
# 1                   Physical and theoretical chemistry       EN
# 2                                              Science       EN
# 3                                            Astronomy       EN
# 4                                              Physics       EN
# ..                                                 ...      ...
# 213                                                NaN      NaN
# 214                                                NaN      NaN
# 215                                                NaN      NaN
# 216                                                NaN      NaN
# 217                                                NaN      NaN
#
# [218 rows x 7 columns]>

# %% [markdown]
# # Get the article details from DOAJ

# %%
def findjournaldata(results):
    publisher = None
    eissn = None
    pissn = None
    title = None
    doajid = None
    categories = None
    language = None
    notfound = True
    # iterate over the result and try to find where title exactly match
    for result in results:
            if result['bibjson']['title'].lower().strip() == journals.iloc[idx]['title'].lower().strip():
                notfound = False
                publisher = result['bibjson']['publisher']['name'] 
                if 'eissn' in result['bibjson'].keys():
                    eissn = result['bibjson']['eissn'] 
                if 'pissn' in result['bibjson'].keys():
                    pissn = result['bibjson']['pissn'] 

                title = result['bibjson']['title'] 
                doajid = result['id'] 
                categories =  "#".join(  [ s['term'].strip() for s in result['bibjson']['subject'] ] ) 
                language = "#".join(  [ s.strip() for s in result['bibjson']['language'] ] ) 
                
                break
    return notfound, publisher, eissn, pissn, title, doajid, categories, language

# %%
import requests
import urllib.parse
from time import sleep

publishers = []
eissns = []
pissns = []
titles = []
doajids = []
categoriess = []
languages = []
for idx in range(len(journals)):
    if 'doajid' not in journals.columns or journals.iloc[idx]['doajid'] is None or not isinstance(journals.iloc[idx]['doajid'], str):
        searchterm = urllib.parse.quote('bibjson.title:"'+journals.iloc[idx]['title']+'"')
        searchterm = 'https://doaj.org/api/v2/search/journals/'+searchterm
        x = requests.get(searchterm)
        notfound = True
        if x.status_code == 200:
            # iterate over pages
            jsonresult =  x.json()
            if 'total' in jsonresult.keys() :
                for page in range(int(jsonresult['total'])):
                    page = page+1
                    if 'results' in jsonresult.keys():                
                        notfound, publisher, eissn, pissn, title, doajid, categories, language = findjournaldata(jsonresult['results'])
                        if not notfound:
                            publishers.append(publisher)
                            eissns.append(eissn)
                            pissns.append(pissn)
                            titles.append(title)
                            doajids.append(doajid)
                            categoriess.append(categories)
                            languages.append(language)
                            break
                        else:
                            if jsonresult['total'] > 1:
                                # go to next page
                                x = requests.get(searchterm+"?page="+str(page)+"&pageSize=10")
                                print(searchterm+"?page="+str(page)+"&pageSize=10")
                                if x.status_code == 200:
                                    jsonresult =  x.json()
                                else:
                                    break
                
       
        if notfound:
            # test there is new page if yes go there        
            print("Error:", searchterm)
            publishers.append(None)
            eissns.append(None)
            pissns.append(None)
            titles.append(journals.iloc[idx]['title'])
            doajids.append(None)
            categoriess.append(None)
            languages.append(None)
        sleep(3)
    else:
        publishers.append(journals.iloc[idx]['publisher'])
        eissns.append(journals.iloc[idx]['eissn'])
        pissns.append(journals.iloc[idx]['pissn'])
        titles.append(journals.iloc[idx]['title'])
        doajids.append(journals.iloc[idx]['doajid'])
        categoriess.append(journals.iloc[idx]['categories'])
        languages.append(journals.iloc[idx]['language'])
    
# enrich journals
journals['publisher'] = publishers
journals['eissn'] = eissns
journals['pissn'] = pissns
journals['title'] = titles
journals['doajid'] = doajids
journals['categories'] = categoriess
journals['language'] = languages

journals.to_csv('doaj_journals.csv', sep="|", index=False)
# Out:
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ADVANCES%20IN%20PHYSICS-X%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS-PHOTONICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NUCLEAR%20PHYSICS%20AND%20ATOMIC%20ENERGY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%222D%20MATERIALS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ADVANCES%20IN%20NATURAL%20SCIENCES-NANOSCIENCE%20AND%20NANOTECHNOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22APPLIED%20PHYSICS%20EXPRESS%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ASTRONOMICAL%20JOURNAL%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ASTROPHYSICAL%20JOURNAL%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ASTROPHYSICAL%20JOURNAL%20LETTERS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ASTROPHYSICAL%20JOURNAL%20SUPPLEMENT%20SERIES%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22BIOFABRICATION%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22BIOINSPIRATION%20%26%20BIOMIMETICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22BIOMEDICAL%20MATERIALS%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22BIOMEDICAL%20PHYSICS%20%26%20ENGINEERING%20EXPRESS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22CHINESE%20PHYSICS%20B%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22CHINESE%20PHYSICS%20C%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22CHINESE%20PHYSICS%20LETTERS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22CLASSICAL%20AND%20QUANTUM%20GRAVITY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22COMMUNICATIONS%20IN%20THEORETICAL%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22CONVERGENT%20SCIENCE%20PHYSICAL%20ONCOLOGY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22ELECTRONIC%20STRUCTURE%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22EPL%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22EUROPEAN%20JOURNAL%20OF%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22FLEXIBLE%20AND%20PRINTED%20ELECTRONICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22FLUID%20DYNAMICS%20RESEARCH%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22INVERSE%20PROBLEMS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JAPANESE%20JOURNAL%20OF%20APPLIED%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20BREATH%20RESEARCH%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20COSMOLOGY%20AND%20ASTROPARTICLE%20PHYSICS%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20INSTRUMENTATION%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20MICROMECHANICS%20AND%20MICROENGINEERING%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20NEURAL%20ENGINEERING%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20OPTICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS%20A-MATHEMATICAL%20AND%20THEORETICAL%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS%20B-ATOMIC%20MOLECULAR%20AND%20OPTICAL%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS-CONDENSED%20MATTER%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS%20D-APPLIED%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS-ENERGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS%20G-NUCLEAR%20AND%20PARTICLE%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20PHYSICS-MATERIALS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20RADIOLOGICAL%20PROTECTION%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20SEMICONDUCTORS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22JOURNAL%20OF%20STATISTICAL%20MECHANICS-THEORY%20AND%20EXPERIMENT%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22LASER%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22LASER%20PHYSICS%20LETTERS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22MEASUREMENT%20SCIENCE%20AND%20TECHNOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22METHODS%20AND%20APPLICATIONS%20IN%20FLUORESCENCE%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22METROLOGIA%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22MODELLING%20AND%20SIMULATION%20IN%20MATERIALS%20SCIENCE%20AND%20ENGINEERING%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANO%20FUTURES%20%22
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=1&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=2&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=3&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=4&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=5&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=6&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=7&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=8&pageSize=10
# https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22?page=9&pageSize=10
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NANOTECHNOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NONLINEARITY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22NUCLEAR%20FUSION%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PHYSICAL%20BIOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PHYSICA%20SCRIPTA%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PHYSICS%20IN%20MEDICINE%20AND%20BIOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PHYSICS%20WORLD%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PHYSIOLOGICAL%20MEASUREMENT%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PLASMA%20PHYSICS%20AND%20CONTROLLED%20FUSION%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PLASMA%20SCIENCE%20%26%20TECHNOLOGY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PLASMA%20SOURCES%20SCIENCE%20%26%20TECHNOLOGY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22PUBLICATIONS%20OF%20THE%20ASTRONOMICAL%20SOCIETY%20OF%20THE%20PACIFIC%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22QUANTUM%20SCIENCE%20AND%20TECHNOLOGY%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22REPORTS%20ON%20PROGRESS%20IN%20PHYSICS%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22SEMICONDUCTOR%20SCIENCE%20AND%20TECHNOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22SMART%20MATERIALS%20AND%20STRUCTURES%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22SUPERCONDUCTOR%20SCIENCE%20%26%20TECHNOLOGY%20%22
# Error: https://doaj.org/api/v2/search/journals/bibjson.title%3A%22SURFACE%20TOPOGRAPHY-METROLOGY%20AND%20PROPERTIES%20%22

# %%
print(journals.head())
journals.tail()
# Out:
#                                   title        publisher      eissn  \
# 0                         Acta Acustica     EDP Sciences  2681-4617
# 1       Adsorption Science & Technology  SAGE Publishing  2048-4038
# 2                      Advanced Science            Wiley  2198-3844
# 3                 Advances in Astronomy  Hindawi Limited  1687-7977
# 4  Advances in Condensed Matter Physics  Hindawi Limited  1687-8124
#
#        pissn                            doajid  \
# 0        NaN  5f0e13147bff461c84a8c1037d39a13c
# 1  0263-6174  0717c4a8661b460d917559af2f7592a2
# 2        NaN  12576ad4e52044b08510c86120dad6eb
# 3  1687-7969  77f5de55948a444f81b838436e0b14cb
# 4  1687-8108  dc71831a25644a5eae44b1305582c389
#
#                                           categories language
# 0  Acoustics in engineering. Acoustical engineeri...       EN
# 1                 Physical and theoretical chemistry       EN
# 2                                            Science       EN
# 3                                          Astronomy       EN
# 4                                            Physics       EN
#                                             title publisher eissn pissn  \
# 213               REPORTS ON PROGRESS IN PHYSICS       None  None  None
# 214         SEMICONDUCTOR SCIENCE AND TECHNOLOGY       None  None  None
# 215               SMART MATERIALS AND STRUCTURES       None  None  None
# 216          SUPERCONDUCTOR SCIENCE & TECHNOLOGY       None  None  None
# 217  SURFACE TOPOGRAPHY-METROLOGY AND PROPERTIES       None  None  None
#
#     doajid categories language
# 213   None       None     None
# 214   None       None     None
# 215   None       None     None
# 216   None       None     None
# 217   None       None     None

# %% [markdown]
# # Get the articles for the Journal

# %%
def findarticledata(results):
    
    # iterrate over Articles
    url = []
    title = []
    doi = []
    abstract  = []
    writers = []
    publishdate = []
    keyword = []
    for result in results:

        # url
        urlfound = False
        for l in result['bibjson']["link"]:
            if l['type'] == "fulltext":
                urlfound = True
                url.append(  l['url'].replace("\n", "") )
                break
        if not urlfound:
            # if there no url we do not interest about the Article
            url.append(None)
            title.append(None)
            doi.append(None)
            abstract.append( None )
            writers.append(None)
            publishdate.append( None )
            keyword.append( None )
            continue
                
            
        # title
        if "title" in  result['bibjson']:
            title.append( result['bibjson']["title"].replace("\n", "") )
        else:
            # if there no title we do not interest about the Article
            title.append(None)
            doi.append(None)
            abstract.append( None )
            writers.append(None)
            publishdate.append( None )
            keyword.append( None )
            continue
        
        # doi
        founddoi = False
        for ide in result['bibjson']['identifier']:
            if ide["type"].lower() == "doi":
                founddoi = True
                doi.append( ide['id'].replace("\n", "") )
                break
        if not founddoi:
            doi.append(None)
        
        # abstract
        if "abstract" in  result['bibjson']:
            abstract.append( result['bibjson']["abstract"].replace("\n", '<br>') )
        else:
            # if there no abstract we do not interest about the Article
            abstract.append( None )
            writers.append(None)
            publishdate.append( None )
            keyword.append( None )
            continue
        
        # writer
        writer = ""
        for w in result['bibjson']["author"]:
            try:
                writer = writer + "#" + w['name'].replace("\n", "")
                if 'affiliation' in w.keys():
                    writer = writer + "--" + w['affiliation'].replace("\n", "")
                if 'orcid_id' in w.keys():
                    writer = writer + "---" + w['orcid_id'].replace("\n", "")          
            except:
                pass
        if len(writer) > 0:
            writers.append(writer)
        else:
            writers.append(None)
            publishdate.append( None )
            keyword.append( None )
            continue
        
        # publishdate
        if "created_date" in result.keys():
            publishdate.append( result["created_date"].replace("\n", "") )
        else:
            publishdate.append( None )
        
        # keywords
        # we put there a filter as if there is too much keyword the are not informatiom
        if "keywords" in result['bibjson'] and len(result['bibjson']["keywords"]) < 15 :
            keytext = ""            
            for k in result['bibjson']["keywords"]:
                if len(k) < 100:
                    keytext = keytext + "#" + k.replace("\n", "")
            if len(keytext) == 0:
                keyword.append( None )
            else:
                keyword.append( keytext )
        else:
            keyword.append( None )

    df = pd.DataFrame({
        'url': url,
        'title': title,
        'doi': doi,
        'abstract': abstract,
        'writer': writers,
        'publishdate': publishdate,
        'keyword': keyword,
                      })
        
    return df

# %%
def itterate_over_results(searchterm, jsonresult, journals, journaldf, desc=True):
    if 'total' in jsonresult.keys() :                            
            for page in range(pagenumber):
                if 'results' in jsonresult.keys():   
                    thispage = findarticledata(jsonresult['results'])
                    thispage['journal_title'] = journals.iloc[idx]['title']
                    thispage['journal_eissn'] = journals.iloc[idx]['eissn']
                    thispage['journal_pissn'] = journals.iloc[idx]['pissn']
                    thispage['category'] = journals.iloc[idx]['categories']
                    
                    journaldf = pd.concat([journaldf, thispage])                    
                # go to othe next page
                if jsonresult['total'] > 1 and page != pagenumber-1 :
                    sleep(3)
                    # go to next page
                    x = None
                    if desc:
                        x = requests.get(searchterm+"?page="+str(page+2)+"&pageSize=100&sort=bibjson.title:desc")
                    else:
                        x = requests.get(searchterm+"?page="+str(page+2)+"&pageSize=100&sort=bibjson.title:asc")
                    if x.status_code == 200:
                        jsonresult =  x.json()
                    else:
                        break
                        
    return journaldf

# %%
import csv
import numpy as np

# iterate over the journals
for idx in range(len(journals)): 
    print("load:", journals.iloc[idx]['title'], "Ready: ", str(np.round(100*idx/len(journals),2))+"%", end='\r')
    # searchtext = 'journal:"'+journals.iloc[idx]['title']+'" AND _exists_:doi AND _exists_:abstract  AND _exists_: "bibjson.author" '
    searchtext = 'journal:"'+journals.iloc[idx]['title']+'" AND _exists_:abstract  AND _exists_: "bibjson.author" '
    # add issn
    if isinstance(journals.iloc[idx]['eissn'], str):
        searchtext = searchtext + ' AND issn: "'+journals.iloc[idx]['eissn']+'"'
    else:
        if isinstance(journals.iloc[idx]['pissn'], str):
            searchtext = searchtext + ' AND issn: "'+journals.iloc[idx]['pissn']+'"'        
    searchterm = urllib.parse.quote(searchtext)
    searchterm = 'https://doaj.org/api/v2/search/articles/'+searchterm
    x = requests.get(searchterm +'?page=1&pageSize=100&sort=bibjson.title:desc')    
    notfound = True
    
    journaldf  = pd.DataFrame({
        'url': [],
        'title': [],
        'doi': [],
        'abstract': [],
        'writer': [],
        'publishdate': [],
        'keyword': [],
        'journal_title': [],
        'journal_eissn': [],
        'journal_pissn': [],
        'category': []
                      })
    
    if x.status_code == 200:
        # is the dataset fit in the DOAJ 1000 Article filter?
        reruninasc = False
        # iterate over pages
        jsonresult =  x.json()
        if 'total' in jsonresult.keys() :
            pagenumber = int(jsonresult['total']//100)+1
            if jsonresult['total'] > 1000 :                
                reruninasc = True
            if jsonresult['total'] > 2000 :
                print("Can not collect all of the Article for", journals.iloc[idx]['title'], "Total:", jsonresult['total'])
            journaldf = itterate_over_results(searchterm, jsonresult, journals, journaldf, desc=True)
            
        if reruninasc:
            sleep(3)
            x = requests.get(searchterm+"?page=1&pageSize=100&bibjson.title&sort=bibjson.title:asc")
            if x.status_code == 200:
                jsonresult =  x.json()
                journaldf = itterate_over_results(searchterm, jsonresult, journals, journaldf, desc=False)
            
    # drop duplicates
    journaldf.drop_duplicates(inplace=True)
    
    # save journaldf
    journaldf.to_pickle('data/journal_'+journals.iloc[idx]['title'].replace(" ", "_").replace("&", "and")+"_"+version+".pandas" )    
    print("Found", len(journaldf), "article!")
    sleep(10)
# Out:
# Found 21 article!ca Ready:  0.0%
# Can not collect all of the Article for Adsorption Science & Technology Total: 1968
# Found 1893 article!
# Can not collect all of the Article for Advanced Science Total: 1008
# Found 1008 article!
# Found 301 article!Astronomy Ready:  1.38%
# Found 626 article!Condensed Matter Physics Ready:  1.83%
# Can not collect all of the Article for Advances in High Energy Physics Total: 1279
# Found 1265 article!
# Found 967 article!Mathematical Physics  Ready:  2.75%
# Found 137 article!PHYSICS-X  Ready:  3.21%
# Found 152 article!ics Ready:  3.67%
# Can not collect all of the Article for AIP Advances Total: 9660
# Found 1965 article!
# Found 0 article!ociación Física Argentina) Ready:  4.59%
# Can not collect all of the Article for Annales Geophysicae Total: 5077
# Found 1987 article!
# Can not collect all of the Article for Annals of Geophysics Total: 2903
# Found 1965 article!
# Can not collect all of the Article for APL Materials Total: 1409
# Found 1404 article!
# Found 491 article!s Ready:  6.42%
# Found 24 article!ology Ready:  6.88%
# Can not collect all of the Article for Applied Sciences Total: 17680
# Found 1988 article!
# Found 76 article! Science Letters Ready:  7.8%
# Found 289 article!ia Ready:  8.26%
# Found 374 article!  8.72%
# Can not collect all of the Article for Beilstein Journal of Nanotechnology Total: 1926
# Found 1892 article!
# Found 65 article!and Physicobiology Ready:  9.63%
# Found 0 article!ues Ready:  10.09%
# Can not collect all of the Article for Catalysts Total: 3751
# Found 1951 article!
# Found 10 article!ng Astronomy with the Public Journal Ready:  11.01%
# Found 166 article! Interfaces Ready:  11.47%
# Found 464 article!ns Physics Ready:  11.93%
# Found 348 article! оптика Ready:  12.39%
# Found 0 article!n Magnetic Resonance: Part A, Bridging Education and Research Ready:  12.84%
# Found 233 article!tter Ready:  13.3%
# Can not collect all of the Article for Condensed Matter Physics Total: 1074
# Found 1074 article!
# Found 225 article!s to Geophysics and Geodesy Ready:  14.22%
# Can not collect all of the Article for Crystals Total: 2833
# Found 1967 article!
# Found 366 article!ace Science Ready:  15.14%
# Found 291 article!n Journal of Physics Ready:  15.6%
# Found 0 article!of Surface Science and Nanotechnology Ready:  16.06%
# Can not collect all of the Article for Entropy Total: 6147
# Found 1941 article!
# Found 87 article! Metamaterials Ready:  16.97%
# Found 102 article!taics Ready:  17.43%
# Found 16 article! Technology Ready:  17.89%
# Can not collect all of the Article for European Physical Journal C: Particles and Fields Total: 3861
# Found 1994 article!
# Found 587 article!:  18.81%
# Found 304 article! Astronomy and Space Sciences Ready:  19.27%
# Found 981 article! Materials Ready:  19.72%
# Can not collect all of the Article for Frontiers in Physics Total: 1175
# Found 1171 article!
# Found 526 article!dy:  20.64%
# Found 0 article!l Perspectives Letters Ready:  21.1%
# Found 159 article!Transactions Ready:  21.56%
# Found 508 article!Geodynamics Ready:  22.02%
# Found 455 article!i Tektonofizika Ready:  22.48%
# Found 0 article!Ready:  22.94%
# Found 850 article!ady:  23.39%
# Found 184 article! & Environment Ready:  23.85%
# Found 0 article! Laser Science and Engineering Ready:  24.31%
# Found 0 article!nics Journal Ready:  24.77%
# Found 0 article!rnal of Biochemistry and Biophysics Ready:  25.23%
# Found 97 article!dy:  25.69%
# Found 531 article!l Journal of Biological Sciences Ready:  26.15%
# Found 246 article!l Journal of Geophysics Ready:  26.61%
# Found 296 article!l Journal of Optics Ready:  27.06%
# Can not collect all of the Article for International Journal of Photoenergy Total: 1961
# Found 1077 article!
# Found 135 article!l Journal of Smart and Nano Materials Ready:  27.98%
# Found 0 article!urnal of Catalysis Ready:  28.44%
# Found 31 article!сших учебных заведений: Прикладная нелинейная динамика Ready:  28.9%
# Found 0 article!tthey Technology Review  Ready:  29.36%
# Found 178 article!dvanced Ceramics Ready:  29.82%
# Found 316 article!dvanced Dielectrics Ready:  30.28%
# Found 72 article!Applied Biomaterials & Functional Materials Ready:  30.73%
# Found 490 article!sian Ceramic Societies Ready:  31.19%
# Can not collect all of the Article for Journal of Astronomy and Space Sciences Total: 1145
# Found 1142 article!
# Found 0 article! Cellular and Molecular Medicine  Ready:  32.11%
# Found 659 article!nzyme Inhibition and Medicinal Chemistry Ready:  32.57%
# Found 101 article!xperimental Nanoscience Ready:  33.03%
# Can not collect all of the Article for Journal of High Energy Physics Total: 8082
# Found 1998 article!
# Can not collect all of the Article for Journal of Materials Research and Technology Total: 2303
# Found 1961 article!
# Found 280 article!ateriomics Ready:  34.4%
# Can not collect all of the Article for Journal of Nanomaterials Total: 4373
# Found 1942 article!
# Found 0 article! Physics Communications Ready:  35.32%
# Found 0 article! PHYSICS-PHOTONICS  Ready:  35.78%
# Found 10 article!Research of the National Institute of Standards and Technology Ready:  36.24%
# Found 303 article!cience: Advanced Materials and Devices Ready:  36.7%
# Found 375 article!pace Weather and Space Climate  Ready:  37.16%
# Found 103 article!he European Optical Society-Rapid Publications Ready:  37.61%
# Found 257 article!nal of Physics and Technical Sciences Ready:  38.07%
# Found 405 article!ce & Applications Ready:  38.53%
# Found 0 article!e Ready:  38.99%
# Found 148 article!ws in Relativity Ready:  39.45%
# Found 74 article!ews in Solar Physics Ready:  39.91%
# Found 40 article!sonance in Solids Ready:  40.37%
# Found 206 article!stry Ready:  40.83%
# Found 5 article!rometry Letters Ready:  41.28%
# Found 0 article!Research Express Ready:  41.74%
# Found 299 article!search Letters Ready:  42.2%
# Found 92 article!oday Advances Ready:  42.66%
# Found 160 article!adiation at Extremes Ready:  43.12%
# Can not collect all of the Article for Metals Total: 4920
# Found 1963 article!
# Found 234 article!d Measurement Systems Ready:  44.04%
# Found 63 article!ano Engineering Ready:  44.5%
# Found 104 article!stems Biology Ready:  44.95%
# Found 449 article!y:  45.41%
# Found 53 article!tes Ready:  45.87%
# Found 145 article!ence Ready:  46.33%
# Can not collect all of the Article for Nanomaterials Total: 5869
# Found 1978 article!
# Found 171 article!s and Nanotechnology Ready:  47.25%
# Found 401 article!etters Ready:  47.71%
# Found 686 article!s Ready:  48.17%
# Can not collect all of the Article for Nanoscale Research Letters Total: 2744
# Found 1983 article!
# Found 66 article!ogy Reviews Ready:  49.08%
# Found 1 article!l of Physics Ready:  49.54%
# Found 71 article!ng Ready:  50.0%
# Can not collect all of the Article for Nonlinear Processes in Geophysics Total: 1417
# Found 1417 article!
# Found 146 article!ials and Applications Ready:  50.92%
# Found 404 article!ional Materials Ready:  51.38%
# Found 285 article!Information Ready:  51.83%
# Found 239 article!Materials Ready:  52.29%
# Found 0 article!YSICS AND ATOMIC ENERGY Ready:  52.75%
# Can not collect all of the Article for Nuclear Physics B Total: 1875
# Found 1783 article!
# Found 0 article!ids Research Ready:  53.67%
# Found 296 article!eady:  54.13%
# Found 496 article!my Ready:  54.59%
# Found 578 article! Ready:  55.05%
# Found 0 article!dy:  55.5%
# Found 0 article!terials Express Ready:  55.96%
# Found 0 article!ress Ready:  56.42%
# Found 0 article!uum Ready:  56.88%
# Found 109 article!ysics Ready:  57.34%
# Found 502 article!ady:  57.8%
# Found 158 article!sors Ready:  58.26%
# Can not collect all of the Article for Physical Review Accelerators and Beams Total: 1071
# Found 1071 article!
# Found 427 article!iew Physics Education Research Ready:  59.17%
# Can not collect all of the Article for Physical Review X Total: 1742
# Found 1725 article!
# Found 472 article!ія твердого тіла Ready:  60.09%
# Can not collect all of the Article for Physics Letters B Total: 5281
# Found 1999 article!
# Found 453 article!nd Application of Ceramics Ready:  61.01%
# Found 633 article!Natural Science: Materials International Ready:  61.47%
# Found 0 article!f Theoretical and Experimental Physics Ready:  61.93%
# Found 57 article!Ready:  62.39%
# Found 362 article!y:  62.84%
# Found 99 article!m Science Ready:  63.3%
# Can not collect all of the Article for Results in Physics Total: 3371
# Found 1932 article!
# Found 16 article!ana de Física Ready:  64.22%
# Can not collect all of the Article for Science and Technology of Advanced Materials Total: 1176
# Found 1173 article!
# Found 523 article!ics Ready:  65.14%
# Found 269 article!r Physics, Quantum Electronics & Optoelectronics  Ready:  65.6%
# Found 454 article!onomical Journal Ready:  66.06%
# Found 211 article!trial Physics Ready:  66.51%
# Found 760 article!Ready:  66.97%
# Found 306 article!ynamics Ready:  67.43%
# Found 852 article!tegrability and Geometry: Methods and Applications Ready:  67.89%
# Found 688 article!dy:  68.35%
# Found 954 article!rskogo Gosudarstvennogo Tehničeskogo Universiteta. Seriâ: Fiziko-Matematičeskie Nauki Ready:  68.81%
# Found 146 article!  Ready:  69.27%
# Found 0 article!N NATURAL SCIENCES-NANOSCIENCE AND NANOTECHNOLOGY  Ready:  69.72%
# Found 0 article!YSICS EXPRESS Ready:  70.18%
# Found 456 article! JOURNAL  Ready:  70.64%
# Found 0 article!CAL JOURNAL  Ready:  71.1%
# Found 0 article!CAL JOURNAL LETTERS  Ready:  71.56%
# Found 0 article!CAL JOURNAL SUPPLEMENT SERIES  Ready:  72.02%
# Found 0 article!TION  Ready:  72.48%
# Found 0 article!TION & BIOMIMETICS  Ready:  72.94%
# Found 0 article! MATERIALS Ready:  73.39%
# Found 0 article! PHYSICS & ENGINEERING EXPRESS  Ready:  73.85%
# Found 0 article!YSICS B  Ready:  74.31%
# Found 0 article!YSICS C  Ready:  74.77%
# Found 0 article!YSICS LETTERS  Ready:  75.23%
# Found 0 article!AND QUANTUM GRAVITY  Ready:  75.69%
# Found 0 article!IONS IN THEORETICAL PHYSICS  Ready:  76.15%
# Found 0 article! SCIENCE PHYSICAL ONCOLOGY Ready:  76.61%
# Found 0 article! STRUCTURE Ready:  77.06%
# Found 0 article!tal Research Communications Ready:  77.52%
# Found 0 article!tal Research Letters Ready:  77.98%
# Found 0 article!:  78.44%
# Found 291 article!RNAL OF PHYSICS  Ready:  78.9%
# Found 0 article!ND PRINTED ELECTRONICS  Ready:  79.36%
# Found 0 article!MICS RESEARCH  Ready:  79.82%
# Found 0 article!OBLEMS  Ready:  80.28%
# Found 0 article!OURNAL OF APPLIED PHYSICS  Ready:  80.73%
# Found 0 article! BREATH RESEARCH  Ready:  81.19%
# Found 0 article! COSMOLOGY AND ASTROPARTICLE PHYSICS Ready:  81.65%
# Found 0 article! INSTRUMENTATION  Ready:  82.11%
# Found 0 article! MICROMECHANICS AND MICROENGINEERING  Ready:  82.57%
# Found 0 article! NEURAL ENGINEERING  Ready:  83.03%
# Found 296 article!PTICS  Ready:  83.49%
# Found 0 article! PHYSICS A-MATHEMATICAL AND THEORETICAL Ready:  83.94%
# Found 0 article! PHYSICS B-ATOMIC MOLECULAR AND OPTICAL PHYSICS  Ready:  84.4%
# Found 0 article! PHYSICS-CONDENSED MATTER  Ready:  84.86%
# Found 0 article! PHYSICS D-APPLIED PHYSICS  Ready:  85.32%
# Found 0 article! PHYSICS-ENERGY  Ready:  85.78%
# Found 0 article! PHYSICS G-NUCLEAR AND PARTICLE PHYSICS  Ready:  86.24%
# Found 0 article! PHYSICS-MATERIALS  Ready:  86.7%
# Found 0 article! RADIOLOGICAL PROTECTION  Ready:  87.16%
# Found 0 article! SEMICONDUCTORS  Ready:  87.61%
# Found 0 article! STATISTICAL MECHANICS-THEORY AND EXPERIMENT  Ready:  88.07%
# Found 0 article!ICS  Ready:  88.53%
# Found 0 article!ICS LETTERS  Ready:  88.99%
# Found 0 article!T SCIENCE AND TECHNOLOGY  Ready:  89.45%
# Found 0 article!D APPLICATIONS IN FLUORESCENCE  Ready:  89.91%
# Found 0 article!  Ready:  90.37%
# Found 0 article!AND SIMULATION IN MATERIALS SCIENCE AND ENGINEERING  Ready:  90.83%
# Found 0 article!ES  Ready:  91.28%
# Can not collect all of the Article for NANOTECHNOLOGY  Total: 2907
# Found 1996 article!
# Found 0 article!TY Ready:  92.2%
# Found 0 article!SION  Ready:  92.66%
# Found 0 article!IOLOGY  Ready:  93.12%
# Found 0 article!RIPTA  Ready:  93.58%
# Found 0 article! MEDICINE AND BIOLOGY  Ready:  94.04%
# Found 0 article!RLD  Ready:  94.5%
# Found 0 article!CAL MEASUREMENT Ready:  94.95%
# Found 0 article!SICS AND CONTROLLED FUSION  Ready:  95.41%
# Found 0 article!ENCE & TECHNOLOGY Ready:  95.87%
# Found 0 article!RCES SCIENCE & TECHNOLOGY Ready:  96.33%
# Found 0 article!NS OF THE ASTRONOMICAL SOCIETY OF THE PACIFIC  Ready:  96.79%
# Found 0 article!IENCE AND TECHNOLOGY Ready:  97.25%
# Found 0 article! PROGRESS IN PHYSICS  Ready:  97.71%
# Found 0 article!TOR SCIENCE AND TECHNOLOGY  Ready:  98.17%
# Found 0 article!RIALS AND STRUCTURES  Ready:  98.62%
# Found 0 article!CTOR SCIENCE & TECHNOLOGY  Ready:  99.08%
# Found 0 article!POGRAPHY-METROLOGY AND PROPERTIES  Ready:  99.54%
